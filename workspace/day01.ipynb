# %%
# 파이썬 API를 이용한 가상화폐 시스템
#!pip install pybithumb
# Out:
# Collecting pybithumb
#   Downloading pybithumb-1.0.21-py3-none-any.whl (9.9 kB)
# Collecting html5lib
#   Downloading html5lib-1.1-py2.py3-none-any.whl (112 kB)
#      -------------------------------------- 112.2/112.2 KB 3.2 MB/s eta 0:00:00
# Collecting pandas
#   Downloading pandas-1.4.1-cp39-cp39-win_amd64.whl (10.5 MB)
#      --------------------------------------- 10.5/10.5 MB 16.4 MB/s eta 0:00:00
# Collecting datetime
#   Downloading DateTime-4.4-py2.py3-none-any.whl (51 kB)
#      ---------------------------------------- 51.7/51.7 KB 1.3 MB/s eta 0:00:00
# Collecting websockets
#   Downloading websockets-10.2-cp39-cp39-win_amd64.whl (97 kB)
#      ---------------------------------------- 97.8/97.8 KB 2.7 MB/s eta 0:00:00
# Collecting requests
#   Downloading requests-2.27.1-py2.py3-none-any.whl (63 kB)
#      ---------------------------------------- 63.1/63.1 KB 3.3 MB/s eta 0:00:00
# Collecting bs4
#   Downloading bs4-0.0.1.tar.gz (1.1 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.10.0-py3-none-any.whl (97 kB)
#      ---------------------------------------- 97.4/97.4 KB 5.4 MB/s eta 0:00:00
# Collecting pytz
#   Downloading pytz-2022.1-py2.py3-none-any.whl (503 kB)
#      ------------------------------------- 503.5/503.5 KB 15.9 MB/s eta 0:00:00
# Collecting zope.interface
#   Downloading zope.interface-5.4.0-cp39-cp39-win_amd64.whl (210 kB)
#      ------------------------------------- 210.7/210.7 KB 13.4 MB/s eta 0:00:00
# Collecting webencodings
#   Downloading webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: six>=1.9 in c:\users\jinuk\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from html5lib->pybithumb) (1.16.0)
# Collecting numpy>=1.18.5
#   Downloading numpy-1.22.3-cp39-cp39-win_amd64.whl (14.7 MB)
#      --------------------------------------- 14.7/14.7 MB 15.2 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\jinuk\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas->pybithumb) (2.8.2)
# Collecting urllib3<1.27,>=1.21.1
#   Downloading urllib3-1.26.9-py2.py3-none-any.whl (138 kB)
#      -------------------------------------- 139.0/139.0 KB 4.2 MB/s eta 0:00:00
# Collecting charset-normalizer~=2.0.0
#   Downloading charset_normalizer-2.0.12-py3-none-any.whl (39 kB)
# Collecting certifi>=2017.4.17
#   Downloading certifi-2021.10.8-py2.py3-none-any.whl (149 kB)
#      -------------------------------------- 149.2/149.2 KB 4.3 MB/s eta 0:00:00
#   WARNING: The script f2py.exe is installed in 'C:\Users\jinuk\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script normalizer.exe is installed in 'C:\Users\jinuk\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Collecting idna<4,>=2.5
#   Downloading idna-3.3-py3-none-any.whl (61 kB)
#      ---------------------------------------- 61.2/61.2 KB ? eta 0:00:00
# Collecting soupsieve>1.2
#   Downloading soupsieve-2.3.1-py3-none-any.whl (37 kB)
# Requirement already satisfied: setuptools in c:\program files\windowsapps\pythonsoftwarefoundation.python.3.9_3.9.3312.0_x64__qbz5n2kfra8p0\lib\site-packages (from zope.interface->datetime->pybithumb) (58.1.0)
# Using legacy 'setup.py install' for bs4, since package 'wheel' is not installed.
# Installing collected packages: webencodings, pytz, certifi, zope.interface, websockets, urllib3, soupsieve, numpy, idna, html5lib, charset-normalizer, requests, pandas, datetime, beautifulsoup4, bs4, pybithumb
#   Running setup.py install for bs4: started
#   Running setup.py install for bs4: finished with status 'done'
# Successfully installed beautifulsoup4-4.10.0 bs4-0.0.1 certifi-2021.10.8 charset-normalizer-2.0.12 datetime-4.4 html5lib-1.1 idna-3.3 numpy-1.22.3 pandas-1.4.1 pybithumb-1.0.21 pytz-2022.1 requests-2.27.1 soupsieve-2.3.1 urllib3-1.26.9 webencodings-0.5.1 websockets-10.2 zope.interface-5.4.0

# %%
import pybithumb

# %%
price1 = pybithumb.get_current_price("BTC")
price2 = pybithumb.get_current_price("ETH")
print(price1)
print(price2)
# Out:
# 56363000.0
# 3973000.0

# %%
tickers = pybithumb.get_tickers()

for i in tickers:
    price = pybithumb.get_current_price(i)
    print(f'{i} = {price}')

print("17 박진욱")
# Out:
# BTC = 56496000.0
# ETH = 3975000.0
# LTC = 156600.0
# ETC = 58600.0
# XRP = 1042.0
# BCH = 451400.0
# QTUM = 10250.0
# BTG = 52950.0
# EOS = 3270.0
# ICX = 1180.0
# TRX = 83.16
# ELF = 477.0
# OMG = 6620.0
# KNC = 3828.0
# GLM = 663.2
# ZIL = 127.2
# WAXP = 433.0
# POWR = 701.0
# LRC = 1332.0
# STEEM = 487.0
# STRAX = 1486.0
# ZRX = 881.2
# REP = 19530.0
# XEM = 139.8
# SNT = 94.0
# ADA = 1416.0
# CTXC = 326.0
# BAT = 1100.0
# WTC = 642.7
# THETA = 4382.0
# LOOM = 120.5
# WAVES = 38290.0
# LINK = 20240.0
# ENJ = 2151.0
# VET = 91.94
# MTL = 2483.0
# IOST = 42.36
# TMTG = 3.668
# QKC = 26.8
# ATOLO = 48.44
# AMO = 2.231
# BSV = 114700.0
# ORBS = 105.9
# TFUEL = 237.5
# VALOR = 677.0
# CON = 41.46
# ANKR = 105.9
# MIX = 14.44
# CRO = 584.4
# FX = 738.3
# CHR = 607.2
# MBL = 15.56
# MXC = 126.2
# FCT2 = 142.6
# TRV = 22.02
# DAD = 178.5
# WOM = 137.9
# SOC = 16.05
# BOA = 141.5
# MEV = 28.05
# SXP = 2115.0
# COS = 21.37
# APIX = 67.22
# EL = 9.164
# BASIC = 6.06
# HIVE = 1376.0
# XPR = 14.72
# VRA = 32.29
# FIT = 2.767
# EGG = 49.91
# BORA = 1130.0
# ARPA = 101.7
# CTC = 1654.0
# APM = 36.1
# CKB = 15.53
# AERGO = 326.9
# ANW = 37.39
# CENNZ = 142.9
# EVZ = 79.77
# CYCLUB = 20.5
# SRM = 3694.0
# QTCON = 8.292
# UNI = 13710.0
# YFI = 28234000.0
# UMA = 9595.0
# AAVE = 204100.0
# COMP = 154100.0
# REN = 510.7
# BAL = 16800.0
# RSR = 20.76
# NMR = 37420.0
# RLC = 2751.0
# UOS = 1411.0
# SAND = 4298.0
# GOM2 = 38.85
# RINGX = 42.38
# BEL = 1294.0
# OBSR = 4.913
# ORC = 529.2
# POLA = 122.8
# AWO = 39.93
# ADP = 50.7
# DVI = 484.7
# GHX = 69.33
# MIR = 2015.0
# MVC = 21.17
# BLY = 26.29
# WOZX = 207.1
# ANV = 570.4
# GRT = 542.9
# MM = 703.8
# BIOT = 43.04
# XNO = 78.77
# SNX = 6505.0
# SOFI = 213.7
# COLA = 198.1
# OXT = 333.7
# LINA = 31.8
# MAP = 30.15
# AQT = 3767.0
# WIKEN = 29.68
# CTSI = 517.5
# MANA = 3287.0
# LPT = 34970.0
# MKR = 2494000.0
# SUSHI = 4859.0
# ASM = 69.89
# PUNDIX = 1118.0
# CELR = 69.53
# CWD = 130.5
# ARW = 1382.0
# FRONT = 683.0
# RLY = 262.6
# OCEAN = 748.2
# BFC = 203.0
# ALICE = 9225.0
# COTI = 314.9
# CAKE = 9695.0
# BNT = 3286.0
# XVS = 13170.0
# CHZ = 323.0
# AXS = 81300.0
# DAO = 3171.0
# DAI = 1200.0
# MATIC = 2040.0
# WOO = 736.0
# BAKE = 824.5
# VELO = 88.49
# BCD = 643.8
# XLM = 279.7
# VSYS = 16.79
# IPX = 61.32
# WICC = 171.2
# ONT = 774.0
# LUNA = 114900.0
# AION = 124.5
# META = 106.0
# KLAY = 1434.0
# ONG = 1004.0
# ALGO = 1147.0
# JST = 73.64
# XTZ = 4756.0
# MLK = 1118.0
# WEMIX = 5850.0
# DOT = 27330.0
# ATOM = 36450.0
# SSX = 64.77
# TEMCO = 6.913
# HIBS = 3.2
# BURGER = 1974.0
# DOGE = 179.1
# KSM = 208100.0
# CTK = 1734.0
# XYM = 184.5
# BNB = 518500.0
# NFT = 0.0022
# SUN = 18.01
# XEC = 0.118
# PCI = 975.0
# SOL = 128200.0
# EGLD = 237500.0
# GO = 30.79
# DFA = 1442.0
# C98 = 2052.0
# MED = 56.76
# 1INCH = 2158.0
# BOBA = 1597.0
# GALA = 321.6
# BTT = 0.0025
# EFI = 523.0
# CSPR = 92.24
# AVAX = 109900.0
# TDROP = 35.4
# SPRT = 2476.0
# NPT = 10140.0
# T = 158.8
# 17 박진욱

# %%
# Out:
# hi
